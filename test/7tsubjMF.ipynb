# %%
### for calculating M/F ratio in HCP 7Tsubj data

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns

# %%
participant_df = pd.read_csv('7Tsubj_unrestricted_schakr28_6_24_2022_14_53_57.csv')
subjects_df = pd.read_csv('participants.tsv',sep='\t')

# %%
subjects_df
# Out:
#      Subject
# 0     100610
# 1     102311
# 2     102816
# 3     104416
# 4     105923
# ..       ...
# 168   942658
# 169   943862
# 170   958976
# 171   966975
# 172   971160
#
# [173 rows x 1 columns]

# %%
subj_MF_df = pd.merge(participant_df, subjects_df, on='Subject', how='inner')

# %%
subj_MF_df
# Out:
#      Subject Release Acquisition Gender    Age  3T_Full_MR_Compl  T1_Count  \
# 0     100610    S900         Q08      M  26-30              True         2
# 1     102311    S500         Q06      F  26-30              True         1
# 2     102816      Q3         Q03      F  26-30              True         1
# 3     104416    S900         Q09      F  31-35              True         2
# 4     105923    MEG2         Q07      F  31-35              True         2
# ..       ...     ...         ...    ...    ...               ...       ...
# 168   942658    S900         Q08      M  26-30              True         2
# 169   943862   S1200         Q09      M  26-30              True         2
# 170   958976    S500         Q05      M  26-30              True         2
# 171   966975    S900         Q12      M  22-25              True         2
# 172   971160   S1200         Q10      M  26-30              True         2
#
# ...

# %%
subj_MF_df.to_csv('7Tsubj_info.csv', index=False)

# %%
member = subj_MF_df[['Subject', 'Gender']].groupby(['Gender']).count()

# %%
member
# Out:
#         Subject
# Gender
# F           104
# M            69
